# %% [markdown]
# # Clase 1 - Introduccion a Python

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# # Cargando las librerias

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.5981931 , 0.41908261, 0.59525631, 0.81342451, 0.68708463,
#        0.67497553, 0.29698366, 0.50221811, 0.29231549, 0.42040906,
#        0.07688299, 0.48702368, 0.43125623, 0.75371482, 0.64098466,
#        0.28005832, 0.80188277, 0.54654952, 0.32194858, 0.49599575,
#        0.92841496, 0.1318864 , 0.78848071, 0.49464237, 0.14275447,
#        0.72830171, 0.22335787, 0.9334506 , 0.80222806, 0.72615972,
#        0.90269604, 0.82559957, 0.76852208, 0.66697443, 0.3321904 ,
#        0.17052802, 0.03630031, 0.56370909, 0.140605  , 0.37123312,
#        0.83525388, 0.79313044, 0.56655918, 0.38238064, 0.51672017,
#        0.77843607, 0.05115007, 0.10675972, 0.00671161, 0.23633704])

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# # Tipos de datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x ='nombre'
x
# Out:
# 'nombre'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_numbers/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(False)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
type(None)
# Out:
# NoneType

# %%
x = 16 
y = 8 
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
    print(x, 'es mejor que', y)
# Out:
# 16 es mejor que 8

# %%
unaLista = [ True, 6<5, 1==3, None is None]
unaLista
# Out:
# [True, False, False, True]

# %% [markdown]
# # El uso de for loop

# %%
for element in unaLista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # lista

# %%
unaLista = ['fisrt', 'second', 'third', 'forth', 'fifth', 'sixth']
unaLista
# Out:
# ['fisrt', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
type(unaLista)
# Out:
# list

# %%
unaLista.sort()
unaLista
# Out:
# ['fifth', 'fisrt', 'forth', 'second', 'sixth', 'third']

# %%
unaLista[:2]
# Out:
# ['fifth', 'fisrt']

# %%
unaLista[:0]
# Out:
# []

# %%
unaLista[:1]
# Out:
# ['fifth']

# %%
unaLista[1:3]
# Out:
# ['fisrt', 'forth']
